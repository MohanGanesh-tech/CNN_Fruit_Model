# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os, sys
import numpy as np
import cv2
import random
from tqdm import tqdm
import pickle
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from skimage.transform import resize
from tensorflow.keras.models import load_model

# %%
tf.test.is_gpu_available(cuda_only=False,min_cuda_compute_capability=None)
# Out:
# WARNING:tensorflow:From <ipython-input-2-4ed6d55a490b>:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
BASE_DIR=os.getcwd()
dataset_dir=os.path.join(BASE_DIR,"Dataset")
categories=os.listdir(dataset_dir)
print(dataset_dir,"\n",categories)
# Out:
# C:\Users\Ganesh PC\Desktop\Final\Dataset
#  ['Apple Braeburn', 'Apple Crimson Snow', 'Apple Golden 1', 'Apple Golden 2', 'Apple Golden 3', 'Apple Granny Smith', 'Apple Pink Lady', 'Apple Red 1', 'Apple Red 2', 'Apple Red 3', 'Apple Red Delicious', 'Apple Red Yellow 1', 'Apple Red Yellow 2', 'Apricot', 'Avocado', 'Avocado ripe', 'Banana', 'Banana Lady Finger', 'Banana Red', 'Beetroot', 'Blueberry', 'Cactus fruit', 'Cantaloupe 1', 'Cantaloupe 2', 'Carambula', 'Cauliflower', 'Cherry 1', 'Cherry 2', 'Cherry Rainier', 'Cherry Wax Black', 'Cherry Wax Red', 'Cherry Wax Yellow', 'Chestnut', 'Clementine', 'Cocos', 'Corn', 'Corn Husk', 'Cucumber Ripe', 'Cucumber Ripe 2', 'Dates', 'Eggplant', 'Fig', 'Ginger Root', 'Granadilla', 'Grape Blue', 'Grape Pink', 'Grape White', 'Grape White 2', 'Grape White 3', 'Grape White 4', 'Grapefruit Pink', 'Grapefruit White', 'Guava', 'Hazelnut', 'Huckleberry', 'Kaki', 'Kiwi', 'Kohlrabi', 'Kumquats', 'Lemon', 'Lemon Meyer', 'Limes', 'Lychee', 'Mandarine', 'Mango', 'Mango Red', 'Mangostan', 'Maracuja', 'Melon Piel de Sapo', 'Mulberry', 'Nectarine', 'Nectarine Flat', 'Nut Forest', 'Nut Pecan', 'Onion Red', 'Onion Red Peeled', 'Onion White', 'Orange', 'Papaya', 'Passion Fruit', 'Peach', 'Peach 2', 'Peach Flat', 'Pear', 'Pear 2', 'Pear Abate', 'Pear Forelle', 'Pear Kaiser', 'Pear Monster', 'Pear Red', 'Pear Stone', 'Pear Williams', 'Pepino', 'Pepper Green', 'Pepper Orange', 'Pepper Red', 'Pepper Yellow', 'Physalis', 'Physalis with Husk', 'Pineapple', 'Pineapple Mini', 'Pitahaya Red', 'Plum', 'Plum 2', 'Plum 3', 'Pomegranate', 'Pomelo Sweetie', 'Potato Red', 'Potato Red Washed', 'Potato Sweet', 'Potato White', 'Quince', 'Rambutan', 'Raspberry', 'Redcurrant', 'Salak', 'Strawberry', 'Strawberry Wedge', 'Tamarillo', 'Tangelo', 'Tomato 1', 'Tomato 2', 'Tomato 3', 'Tomato 4', 'Tomato Cherry Red', 'Tomato Heart', 'Tomato Maroon', 'Tomato not Ripened', 'Tomato Yellow', 'Walnut', 'Watermelon']

# %%
training_data = []
IMG_SIZE = 100
def create_training_data():
    print("Please Wait it will take some time")
    for category in categories:
        path = os.path.join(dataset_dir,category)
        class_num = categories.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
                new_array = cv2.resize(img_array, (IMG_SIZE,IMG_SIZE))
                training_data.append([new_array,class_num])
                
            except Exception as e:
                print(e)
                pass
            
create_training_data()
print("\n \n Total Traning Data Length",len(training_data))
# Out:
# Please Wait it will take some time
#
#
#  Total Traning Data Length 67692

# %%
random.shuffle(training_data)

# %%
X = []
y = []

for features,labels in training_data:
    X.append(features)
    y.append(labels)
    
X = np.array(X).reshape(-1,IMG_SIZE,IMG_SIZE,1)
y = np.array(y)

# %%
pickle_out = open("X.pickle","wb")
pickle.dump(X,pickle_out)
pickle_out.close()

pickle_out = open("y.pickle","wb")
pickle.dump(y,pickle_out)
pickle_out.close()

del X,y

# %%
X = []
y = []

X = pickle.load(open("X.pickle","rb"))
y = pickle.load(open("y.pickle","rb"))

x_train, x_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

y_train_one_hot = to_categorical(y_train)
y_test_one_hot = to_categorical(y_test)

del labels,features,y_train,y_test,X,y

x_train = x_train / 255
x_test = x_test / 255

# %%
model = Sequential()

model.add(Conv2D(64, (3,3), input_shape = x_train.shape[1:],activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64,3,3, activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())

model.add(Dense(512,activation= 'relu'))

model.add(Dense(512,activation= 'relu'))
model.add(Dense(len(categories), activation='softmax'))

model.compile(loss="mean_squared_error",optimizer='adam',metrics=['accuracy'])


checkpoint_path="saved_models/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,save_weights_only=True,verbose=1, period=5)


hist = model.fit(x_train, y_train_one_hot,batch_size=50, epochs=25, validation_split=0.3, callbacks=[cp_callback] )

model.summary()

model.evaluate(x_test, y_test_one_hot)[1]

history_dict = hist.history
print(history_dict.keys())
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/25
# 759/759 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 0.2549
# Epoch 00001: saving model to saved_models\cp.ckpt
# 759/759 [==============================] - 28s 37ms/step - loss: 0.0063 - accuracy: 0.2549 - val_loss: 0.0036 - val_accuracy: 0.6514
# Epoch 2/25
# 757/759 [============================>.] - ETA: 0s - loss: 0.0023 - accuracy: 0.7930
# Epoch 00002: saving model to saved_models\cp.ckpt
# 759/759 [==============================] - 27s 36ms/step - loss: 0.0023 - accuracy: 0.7931 - val_loss: 0.0014 - val_accuracy: 0.8744
# Epoch 3/25
# 757/759 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9066
# Epoch 00003: saving model to saved_models\cp.ckpt
# 759/759 [==============================] - 27s 36ms/step - loss: 0.0011 - accuracy: 0.9066 - val_loss: 0.0011 - val_accuracy: 0.8993
# Epoch 4/25
# 758/759 [============================>.] - ETA: 0s - loss: 7.4618e-04 - accuracy: 0.9357
# Epoch 00004: saving model to saved_models\cp.ckpt
# 759/759 [==============================] - 27s 36ms/step - loss: 7.4605e-04 - accuracy: 0.9357 - val_loss: 6.6433e-04 - val_accuracy: 0.9446
# Epoch 5/25
# 757/759 [============================>.] - ETA: 0s - loss: 5.4989e-04 - accuracy: 0.9529 ETA: 0s - loss: 5.5201e-04
# Epoch 00005: saving model to saved_models\cp.ckpt
# 759/759 [==============================] - 27s 35ms/step - loss: 5.4951e-04 - accuracy: 0.9530 - val_loss: 5.8580e-04 - val_accuracy: 0.9496
# Epoch 6/25
# 758/759 [============================>.] - ETA: 0s - loss: 5.0373e-04 - accuracy: 0.9568
# Epoch 00006: saving model to saved_models\cp.ckpt
# 759/759 [==============================] - 27s 36ms/step - loss: 5.0365e-04 - accuracy: 0.9568 - val_loss: 5.4675e-04 - val_accuracy: 0.9533
# Epoch 7/25
# 758/759 [============================>.] - ETA: 0s - loss: 3.9344e-04 - accuracy: 0.9673
# Epoch 00007: saving model to saved_models\cp.ckpt
# 759/759 [==============================] - 27s 36ms/step - loss: 3.9337e-04 - accuracy: 0.9673 - val_loss: 4.6096e-04 - val_accuracy: 0.9617
# Epoch 8/25
# 757/759 [============================>.] - ETA: 0s - loss: 3.5485e-04 - accuracy: 0.9706
# Epoch 00008: saving model to saved_models\cp.ckpt
# 759/759 [==============================] - 27s 36ms/step - loss: 3.5494e-04 - accuracy: 0.9706 - val_loss: 3.8478e-04 - val_accuracy: 0.9674
# Epoch 9/25
# 758/759 [============================>.] - ETA: 0s - loss: 3.0860e-04 - accuracy: 0.9746
# Epoch 00009: saving model to saved_models\cp.ckpt
# 759/759 [==============================] - 27s 36ms/step - loss: 3.0855e-04 - accuracy: 0.9746 - val_loss: 3.3587e-04 - val_accuracy: 0.9714
# Epoch 10/25
# 758/759 [============================>.] - ETA: 0s - loss: 3.2595e-04 - accuracy: 0.9725
# Epoch 00010: saving model to saved_models\cp.ckpt
# 759/759 [==============================] - 28s 36ms/step - loss: 3.2589e-04 - accuracy: 0.9725 - val_loss: 2.5484e-04 - val_accuracy: 0.9785
# Epoch 11/25
# 757/759 [============================>.] - ETA: 0s - loss: 2.9478e-04 - accuracy: 0.9755
# Epoch 00011: saving model to saved_models\cp.ckpt
# 759/759 [==============================] - 27s 36ms/step - loss: 2.9454e-04 - accuracy: 0.9755 - val_loss: 6.4513e-04 - val_accuracy: 0.9468
# Epoch 12/25
# 758/759 [============================>.] - ETA: 0s - loss: 3.4800e-04 - accuracy: 0.9712
# Epoch 00012: saving model to saved_models\cp.ckpt
# 759/759 [==============================] - 27s 36ms/step - loss: 3.4793e-04 - accuracy: 0.9712 - val_loss: 2.9712e-04 - val_accuracy: 0.9746
# Epoch 13/25
# 757/759 [============================>.] - ETA: 0s - loss: 2.3985e-04 - accuracy: 0.9801
# Epoch 00013: saving model to saved_models\cp.ckpt
# 759/759 [==============================] - 27s 36ms/step - loss: 2.3964e-04 - accuracy: 0.9801 - val_loss: 3.4943e-04 - val_accuracy: 0.9697
# Epoch 14/25
# 757/759 [============================>.] - ETA: 0s - loss: 2.4592e-04 - accuracy: 0.9796
# Epoch 00014: saving model to saved_models\cp.ckpt
# 759/759 [==============================] - 28s 37ms/step - loss: 2.4558e-04 - accuracy: 0.9796 - val_loss: 2.7498e-04 - val_accuracy: 0.9767
# Epoch 15/25
# 757/759 [============================>.] - ETA: 0s - loss: 2.2624e-04 - accuracy: 0.9813
# Epoch 00015: saving model to saved_models\cp.ckpt
# 759/759 [==============================] - 29s 38ms/step - loss: 2.2605e-04 - accuracy: 0.9813 - val_loss: 3.3487e-04 - val_accuracy: 0.9718
# Epoch 16/25
# 757/759 [============================>.] - ETA: 0s - loss: 2.1061e-04 - accuracy: 0.9825
# Epoch 00016: saving model to saved_models\cp.ckpt
# 759/759 [==============================] - 28s 37ms/step - loss: 2.1102e-04 - accuracy: 0.9824 - val_loss: 2.3916e-04 - val_accuracy: 0.9799
# Epoch 17/25
# 757/759 [============================>.] - ETA: 0s - loss: 2.1972e-04 - accuracy: 0.9817
# Epoch 00017: saving model to saved_models\cp.ckpt
# 759/759 [==============================] - 28s 37ms/step - loss: 2.1986e-04 - accuracy: 0.9817 - val_loss: 1.7396e-04 - val_accuracy: 0.9859
# Epoch 18/25
# 757/759 [============================>.] - ETA: 0s - loss: 2.2822e-04 - accuracy: 0.9811
# Epoch 00018: saving model to saved_models\cp.ckpt
# 759/759 [==============================] - 27s 35ms/step - loss: 2.2829e-04 - accuracy: 0.9811 - val_loss: 2.7240e-04 - val_accuracy: 0.9777
# Epoch 19/25
# 757/759 [============================>.] - ETA: 0s - loss: 1.8123e-04 - accuracy: 0.9853
# Epoch 00019: saving model to saved_models\cp.ckpt
# 759/759 [==============================] - 27s 36ms/step - loss: 1.8135e-04 - accuracy: 0.9853 - val_loss: 1.7879e-04 - val_accuracy: 0.9857
# Epoch 20/25
# 757/759 [============================>.] - ETA: 0s - loss: 1.8688e-04 - accuracy: 0.9844
# Epoch 00020: saving model to saved_models\cp.ckpt
# 759/759 [==============================] - 28s 37ms/step - loss: 1.8663e-04 - accuracy: 0.9844 - val_loss: 2.3536e-04 - val_accuracy: 0.9802
# Epoch 21/25
# 757/759 [============================>.] - ETA: 0s - loss: 1.5805e-04 - accuracy: 0.9868
# Epoch 00021: saving model to saved_models\cp.ckpt
# 759/759 [==============================] - 28s 36ms/step - loss: 1.5829e-04 - accuracy: 0.9868 - val_loss: 2.0361e-04 - val_accuracy: 0.9830
# Epoch 22/25
# 757/759 [============================>.] - ETA: 0s - loss: 2.0138e-04 - accuracy: 0.9831
# Epoch 00022: saving model to saved_models\cp.ckpt
# 759/759 [==============================] - 28s 37ms/step - loss: 2.0108e-04 - accuracy: 0.9832 - val_loss: 2.5476e-04 - val_accuracy: 0.9787
# Epoch 23/25
# 757/759 [============================>.] - ETA: 0s - loss: 1.4487e-04 - accuracy: 0.9880
# Epoch 00023: saving model to saved_models\cp.ckpt
# 759/759 [==============================] - 29s 38ms/step - loss: 1.4501e-04 - accuracy: 0.9880 - val_loss: 1.9315e-04 - val_accuracy: 0.9835
# Epoch 24/25
# 757/759 [============================>.] - ETA: 0s - loss: 1.3451e-04 - accuracy: 0.9888
# Epoch 00024: saving model to saved_models\cp.ckpt
# 759/759 [==============================] - 28s 37ms/step - loss: 1.3455e-04 - accuracy: 0.9888 - val_loss: 1.8781e-04 - val_accuracy: 0.9843
# Epoch 25/25
# 757/759 [============================>.] - ETA: 0s - loss: 1.7989e-04 - accuracy: 0.9848
# Epoch 00025: saving model to saved_models\cp.ckpt
# 759/759 [==============================] - 28s 37ms/step - loss: 1.7965e-04 - accuracy: 0.9848 - val_loss: 1.4792e-04 - val_accuracy: 0.9879
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 98, 98, 64)        640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 49, 49, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               524416
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 131)               8515
# =================================================================
# Total params: 578,755
# Trainable params: 578,755
# Non-trainable params: 0
# _________________________________________________________________
# 424/424 [==============================] - 4s 9ms/step - loss: 1.6009e-04 - accuracy: 0.9864
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
latest = tf.train.latest_checkpoint(checkpoint_dir)

model.load_weights(latest)
model.summary()

model.evaluate(x_test, y_test_one_hot)[1]
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 98, 98, 64)        640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 49, 49, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               524416
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 131)               8515
# =================================================================
# Total params: 578,755
# Trainable params: 578,755
# Non-trainable params: 0
# _________________________________________________________________
# 424/424 [==============================] - 4s 8ms/step - loss: 1.6009e-04 - accuracy: 0.9864
# 0.986409604549408

# %%
image_add='C:/Users/Ganesh PC/Desktop/Final/Test/75_100.jpg'
my_image = plt.imread(image_add)
plt.imshow(my_image)
my_image_resized = resize(my_image, (IMG_SIZE,IMG_SIZE,1))
probabilities = model.predict(np.array( [my_image_resized,] ))

index = np.argsort(probabilities[0,:])
print("Predicted Class:", categories[index[len(categories)-1]],"\nProbability:", probabilities[0,index[len(categories)-1]]*100)
# Out:
# Predicted Class: Apple Golden 1
# Probability: 99.99873638153076
